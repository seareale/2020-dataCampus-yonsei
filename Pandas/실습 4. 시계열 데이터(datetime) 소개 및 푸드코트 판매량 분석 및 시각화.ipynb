# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib

# %matplotlib inline

# %% [markdown]
# # 1. 시계열 데이터 타입  (datetime)

# %%
from datetime import datetime

# %%
now = datetime.now()

# %%
now.year
# Out:
# 2020

# %%
now.hour
# Out:
# 15

# %% [markdown]
# <img src="img/예제실습/datetime.jpg" alt="datetime" style="width: 1200px;"/>

# %% [markdown]
# ## 1.1 timedelta 를 활용한 시간 계산

# %%
from datetime import timedelta

# %%
now
# Out:
# datetime.datetime(2020, 7, 23, 15, 28, 46, 761764)

# %%
now + timedelta(days = 100)
# weeks, days, hous, minutes, seconds, miliseconds, microseonds
# Out:
# datetime.datetime(2020, 10, 31, 15, 28, 46, 761764)

# %%
# now로부터 3시간 35분 후의 시간 계산
now + timedelta(hours = 3, minutes = 35)
# Out:
# datetime.datetime(2020, 7, 23, 19, 3, 46, 761764)

# %%
now2 = datetime.now()
now2
# Out:
# datetime.datetime(2020, 7, 23, 15, 28, 49, 345110)

# %%
now2 - now
# Out:
# datetime.timedelta(seconds=2, microseconds=583346)

# %% [markdown]
# ## 1.2 편리한 색인

# %%
import random
sample = DataFrame()
sample['날짜'] = pd.date_range(start= '2020-07-23', periods = 180).tolist()
sample['사용자수'] = random.sample(range(1,1000), 180)
sample.head()
# Out:
#           날짜  사용자수
# 0 2020-07-23   319
# 1 2020-07-24   404
# 2 2020-07-25   976
# 3 2020-07-26   971
# 4 2020-07-27    98

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      180 non-null    datetime64[ns]
#  1   사용자수    180 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.9 KB

# %%
# 8월달 데이터만 조회
sample[(sample.날짜 >= '2020-08-01') & (sample.날짜 <= '2020-08-31')]
# Out:
#            날짜  사용자수
# 9  2020-08-01    82
# 10 2020-08-02   848
# 11 2020-08-03   582
# 12 2020-08-04   744
# 13 2020-08-05   861
# 14 2020-08-06   751
# 15 2020-08-07   585
# 16 2020-08-08   714
# 17 2020-08-09   618
# 18 2020-08-10    17
# 19 2020-08-11   189
# 20 2020-08-12   654
# 21 2020-08-13   597
# 22 2020-08-14   602
# 23 2020-08-15   767
# 24 2020-08-16   176
# 25 2020-08-17   894
# 26 2020-08-18   403
# 27 2020-08-19   129
# 28 2020-08-20   456
# 29 2020-08-21   484
# 30 2020-08-22   317
# 31 2020-08-23   283
# 32 2020-08-24   394
# 33 2020-08-25   641
# 34 2020-08-26   450
# 35 2020-08-27   905
# 36 2020-08-28   416
# 37 2020-08-29   990
# 38 2020-08-30   428
# 39 2020-08-31   281

# %%
sample2 = sample.set_index('날짜')

# %%
sample2['2020-08']
# Out:
#             사용자수
# 날짜
# 2020-08-01    82
# 2020-08-02   848
# 2020-08-03   582
# 2020-08-04   744
# 2020-08-05   861
# 2020-08-06   751
# 2020-08-07   585
# 2020-08-08   714
# 2020-08-09   618
# 2020-08-10    17
# 2020-08-11   189
# 2020-08-12   654
# 2020-08-13   597
# 2020-08-14   602
# 2020-08-15   767
# 2020-08-16   176
# 2020-08-17   894
# 2020-08-18   403
# 2020-08-19   129
# 2020-08-20   456
# 2020-08-21   484
# 2020-08-22   317
# 2020-08-23   283
# 2020-08-24   394
# 2020-08-25   641
# 2020-08-26   450
# 2020-08-27   905
# 2020-08-28   416
# 2020-08-29   990
# 2020-08-30   428
# 2020-08-31   281

# %%
sample2.info()
# row index가 DatetimeIndex 인 경우에만
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 180 entries, 2020-07-23 to 2021-01-18
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용자수    180 non-null    int64
# dtypes: int64(1)
# memory usage: 2.8 KB

# %%
# 2021년 데이터만 선택
sample2['2021']
# Out:
#             사용자수
# 날짜
# 2021-01-01   329
# 2021-01-02   562
# 2021-01-03   914
# 2021-01-04   558
# 2021-01-05    47
# 2021-01-06   118
# 2021-01-07   493
# 2021-01-08   476
# 2021-01-09   310
# 2021-01-10   603
# 2021-01-11   266
# 2021-01-12   107
# 2021-01-13    26
# 2021-01-14   244
# 2021-01-15   900
# 2021-01-16   516
# 2021-01-17   995
# 2021-01-18   906

# %%
# 2020년 10월 데이터만 선택
#sample2['2020-10']
sample2['2020/10']
# 실제로는 슬라이싱
# sample2['2020/10/01':'2020/10/31']
# Out:
#             사용자수
# 날짜
# 2020-10-01   201
# 2020-10-02   486
# 2020-10-03   208
# 2020-10-04   182
# 2020-10-05   440
# 2020-10-06   331
# 2020-10-07   452
# 2020-10-08   750
# 2020-10-09   845
# 2020-10-10   537
# 2020-10-11   837
# 2020-10-12   893
# 2020-10-13   358
# 2020-10-14   819
# 2020-10-15   671
# 2020-10-16   987
# 2020-10-17   539
# 2020-10-18   196
# 2020-10-19   542
# 2020-10-20   872
# 2020-10-21   637
# 2020-10-22   726
# 2020-10-23   838
# 2020-10-24    19
# 2020-10-25   133
# 2020-10-26   210
# 2020-10-27   174
# 2020-10-28   694
# 2020-10-29   774
# 2020-10-30     7
# 2020-10-31   799

# %%
# 2020년 10월 3일부터 2020년 11월 20일까지 데이터만 선택
sample2['2020/10/3':'2020/11/20']
# Out:
#             사용자수
# 날짜
# 2020-10-03   208
# 2020-10-04   182
# 2020-10-05   440
# 2020-10-06   331
# 2020-10-07   452
# 2020-10-08   750
# 2020-10-09   845
# 2020-10-10   537
# 2020-10-11   837
# 2020-10-12   893
# 2020-10-13   358
# 2020-10-14   819
# 2020-10-15   671
# 2020-10-16   987
# 2020-10-17   539
# 2020-10-18   196
# 2020-10-19   542
# 2020-10-20   872
# 2020-10-21   637
# 2020-10-22   726
# 2020-10-23   838
# 2020-10-24    19
# 2020-10-25   133
# 2020-10-26   210
# 2020-10-27   174
# 2020-10-28   694
# 2020-10-29   774
# 2020-10-30     7
# 2020-10-31   799
# 2020-11-01   689
# 2020-11-02   769
# 2020-11-03   392
# 2020-11-04    11
# 2020-11-05   883
# 2020-11-06   247
# 2020-11-07   707
# 2020-11-08   461
# 2020-11-09   967
# 2020-11-10   551
# 2020-11-11   865
# 2020-11-12   862
# 2020-11-13   528
# 2020-11-14   454
# 2020-11-15   579
# 2020-11-16   498
# 2020-11-17   194
# 2020-11-18   243
# 2020-11-19   720
# 2020-11-20   533

# %%
# 2020년 12월 25일 데이터만 선택
sample2.loc['2020/12/25']
# Out:
# 사용자수    977
# Name: 2020-12-25 00:00:00, dtype: int64

# %% [markdown]
# ## 1.3 함수 사용  1 - strftime()으로 날짜 타입의 변수를 문자열로 변환하기

# %%
now.strftime('%Y-%m-%d')
# Out:
# '2020-07-23'

# %%
# 달(month)별로 사용자수의 sum을 구하기
sample.pivot_table(index='날짜', values='사용자수', aggfunc='sum')
# Out:
#             사용자수
# 날짜
# 2020-07-23   319
# 2020-07-24   404
# 2020-07-25   976
# 2020-07-26   971
# 2020-07-27    98
# ...          ...
# 2021-01-14   244
# 2021-01-15   900
# 2021-01-16   516
# 2021-01-17   995
# 2021-01-18   906
#
# [180 rows x 1 columns]

# %%
# 딜(month) 컬럼을 추가
# sample.날짜[100].strftime('%m')
sample['달'] = sample.날짜.apply(lambda X: X.strftime('%m'))

# %%
sample.head()
# Out:
#           날짜  사용자수   달
# 0 2020-07-23   319  07
# 1 2020-07-24   404  07
# 2 2020-07-25   976  07
# 3 2020-07-26   971  07
# 4 2020-07-27    98  07

# %%
sample.pivot_table(index='달', values='사용자수', aggfunc='sum')
# Out:
#      사용자수
# 달
# 01   8370
# 07   5109
# 08  16258
# 09  18436
# 10  16157
# 11  16048
# 12  15740

# %%
# 요일별로 사용자수의 sum 구하기
sample['요일'] = sample.날짜.apply(lambda X: X.strftime('%a'))
sample.pivot_table(index='요일', values='사용자수', aggfunc='sum')
# Out:
#       사용자수
# 요일
# Fri  15726
# Mon  13092
# Sat  13833
# Sun  14590
# Thu  15030
# Tue  10980
# Wed  12867

# %% [markdown]
# ## 1-3 함수 사용 2 - strptime()으로 문자열을 날짜 타입으로 변환하기

# %%
문자열 = '20/08/17'

# %%
datetime.strptime(문자열, '%y/%m/%d')
# Out:
# datetime.datetime(2020, 8, 17, 0, 0)

# %% [markdown]
# ### (실습 #1) 아래 df에서 2019년 7월 데이터만 선택하기

# %%
df = DataFrame({'date':['2019-07-01','2019-07-02', '2019-07-05', '2019-07-10', '2019-07-23', 
                        '2019-07-24','2019-07-28', '2019-08-05', '2019-08-10', '2019-08-23'],
                'value':random.sample(range(1, 100), 10)
})
df
# Out:
#          date  value
# 0  2019-07-01     24
# 1  2019-07-02     90
# 2  2019-07-05     15
# 3  2019-07-10     82
# 4  2019-07-23     51
# 5  2019-07-24     74
# 6  2019-07-28     97
# 7  2019-08-05     92
# 8  2019-08-10     84
# 9  2019-08-23     87

# %%
df2 = df.set_index('date')
df2.index = pd.to_datetime(df['date'])
#df2.info()
df2['2019-07']

# %%
# 첫번째 방법
# 날짜 컬럼을 String -> Datetime타입으로 변환
# strptime() 함수 활용
# datetime.strptime(df.날짜[3], '%Y-%m-%d')
df.date.apply(lambda X: datetime.strptime(X, '%Y-%m-%d'))
# Out:
# 0   2019-07-01
# 1   2019-07-02
# 2   2019-07-05
# 3   2019-07-10
# 4   2019-07-23
# 5   2019-07-24
# 6   2019-07-28
# 7   2019-08-05
# 8   2019-08-10
# 9   2019-08-23
# Name: date, dtype: datetime64[ns]

# %%
# 두번째 방법
# pd.to_datetime() 함수 활용
pd.to_datetime(df.date, format = '%Y-%m-%d')
# Out:
# 0   2019-07-01
# 1   2019-07-02
# 2   2019-07-05
# 3   2019-07-10
# 4   2019-07-23
# 5   2019-07-24
# 6   2019-07-28
# 7   2019-08-05
# 8   2019-08-10
# 9   2019-08-23
# Name: date, dtype: datetime64[ns]

# %%
# 세번째 방법 .astype() 함수 활용

df['date'] = df.date.astype('datetime64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    10 non-null     datetime64[ns]
#  1   value   10 non-null     int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 288.0 bytes

# %% [markdown]
# ## Tip. Week와 요일 정보 얻기(strftime)

# %%
now
# Out:
# datetime.datetime(2020, 7, 23, 15, 28, 46, 761764)

# %%
# 심화 - Week와 요일 정보 얻기
# 참고 사이트 : https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %U : week number (sunday to monday) (e.g. 00, 01, ...53)
# %V : ISO 8601 week number (monday to sunday) (e.g. 01, 02, ... 53)
...
# %a : weekday (Sun, Mon, ..) 
# %w : weekday (0,1,2,3,...) (0 = Sunday)

# %%
now.strftime('%W')
# Out:
# '29'

# %%
now.strftime('%V')
# Out:
# '30'

# %% [markdown]
# ### (실습 #2) df에  week number(%V), weekday(%w) 컬럼 추가

# %%
df
# Out:
#         date  value
# 0 2019-07-01     24
# 1 2019-07-02     90
# 2 2019-07-05     15
# 3 2019-07-10     82
# 4 2019-07-23     51
# 5 2019-07-24     74
# 6 2019-07-28     97
# 7 2019-08-05     92
# 8 2019-08-10     84
# 9 2019-08-23     87

# %%
df['week number(%V)'] = df.date.apply(lambda X: X.strftime('%V'))
df
# Out:
#         date  value week number(%V)
# 0 2019-07-01     24              27
# 1 2019-07-02     90              27
# 2 2019-07-05     15              27
# 3 2019-07-10     82              28
# 4 2019-07-23     51              30
# 5 2019-07-24     74              30
# 6 2019-07-28     97              30
# 7 2019-08-05     92              32
# 8 2019-08-10     84              32
# 9 2019-08-23     87              34

# %%
df['weekday(%w)'] = df.date.apply(lambda X: X.strftime('%w'))
df
# Out:
#         date  value week number(%V) weekday(%w)
# 0 2019-07-01     24              27           1
# 1 2019-07-02     90              27           2
# 2 2019-07-05     15              27           5
# 3 2019-07-10     82              28           3
# 4 2019-07-23     51              30           2
# 5 2019-07-24     74              30           3
# 6 2019-07-28     97              30           0
# 7 2019-08-05     92              32           1
# 8 2019-08-10     84              32           6
# 9 2019-08-23     87              34           5

# %% [markdown]
# ### (실습 #3-1) 주차별 value 컬럼의 합 구하기

# %%
df.pivot_table(index = 'week number(%V)', values = 'value', aggfunc='sum')
# Out:
#                  value
# week number(%V)
# 27                 129
# 28                  82
# 30                 222
# 32                 176
# 34                  87

# %% [markdown]
# ### (실습 #3-2) 요일별 value 컬럼의 합 구하기

# %%
df.pivot_table(index = 'weekday(%w)', values = 'value', aggfunc='sum')
# Out:
#              value
# weekday(%w)
# 0               97
# 1              116
# 2              141
# 3              156
# 5              102
# 6               84

# %% [markdown]
# ## 2. 푸드코트 주문 데이터 분석

# %%
# 데이터 읽기
식당 = pd.read_excel('data/food_order.xlsx')

# %%
식당.head()
# Out:
#         date  dine_type         corner          menu is_sold_out  use_count  \
# 0 2013-08-06     dinner    grill & fry  훈제연어벤또(200개)           F        213
# 1 2013-08-06     dinner  rice & soup 1   뚝배기 우거지 갈비탕           F        261
# 2 2013-08-06      lunch     noodle bar         판모밀정식           F        267
# 3 2013-08-06  breakfast  rice & soup 1         설렁탕정식           F          1
# 4 2013-08-06      lunch  rice & soup 1     A. 부대찌개정식           F        376
#
#    pred_count  additional  good  ok  bad  diff_use_pred  year  month  day  \
# 0           0           0     0   0    0           -213  2013      8    6
# 1           0           0     0   0    0           -261  2013      8    6
# 2           0           0     0   0    0           -267  2013      8    6
# 3           0           0     0   0    0             -1  2013      8    6
# 4           0           0     0   0    0           -376  2013      8    6
#
#    wday
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
식당.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6825 entries, 0 to 6824
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           6825 non-null   datetime64[ns]
#  1   dine_type      6825 non-null   object
#  2   corner         6825 non-null   object
#  3   menu           6825 non-null   object
#  4   is_sold_out    6825 non-null   object
#  5   use_count      6825 non-null   int64
#  6   pred_count     6825 non-null   int64
#  7   additional     6825 non-null   int64
#  8   good           6825 non-null   int64
#  9   ok             6825 non-null   int64
#  10  bad            6825 non-null   int64
#  11  diff_use_pred  6825 non-null   int64
#  12  year           6825 non-null   int64
#  13  month          6825 non-null   int64
#  14  day            6825 non-null   int64
#  15  wday           6825 non-null   int64
# dtypes: datetime64[ns](1), int64(11), object(4)
# memory usage: 853.2+ KB

# %%
# 1. 'date' 컬럼을 index label로 지정
식당.set_index('date',inplace =True)

# %%
# 2. 데이터 탐색 - 수집 기간
식당.info()
# DatetimeIndex: 6825 entries, 2013-08-06 to 2015-07-27

식당.index.min(), 식당.index.max()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6825 entries, 2013-08-06 to 2015-07-27
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   dine_type      6825 non-null   object
#  1   corner         6825 non-null   object
#  2   menu           6825 non-null   object
#  3   is_sold_out    6825 non-null   object
#  4   use_count      6825 non-null   int64
#  5   pred_count     6825 non-null   int64
#  6   additional     6825 non-null   int64
#  7   good           6825 non-null   int64
#  8   ok             6825 non-null   int64
#  9   bad            6825 non-null   int64
#  10  diff_use_pred  6825 non-null   int64
#  11  year           6825 non-null   int64
#  12  month          6825 non-null   int64
#  13  day            6825 non-null   int64
#  14  wday           6825 non-null   int64
# dtypes: int64(11), object(4)
# memory usage: 853.1+ KB
# ...

# %%
# 3. 데이터 탐색 - 수집 기간 동안 누락 없이 데이터가 수집되었는지 확인

# 3.1. wday(요일별 데이터) -> 균일한지 확인
식당.wday.value_counts()

# 월~금 데이터 수집
# 주말 데이터 (토,일)은 미수집
# Out:
# 0    1433
# 1    1432
# 2    1373
# 3    1298
# 4    1289
# Name: wday, dtype: int64

# %%
# 3.2. 데이터 수집기간 중 주중날짜만 생성
# pd.date_range() 활용
#pd.date_range(start='2020-07-30', end='2020-10-20')
#pd.date_range(start='2020-07-30', periods=50)  
#pd.date_range(start='2020-07-30', end='2020-10-20', periods=50) # 해당 기간을 균등한 간격으로 나누기
#pd.date_range(start='2020-07-30', end='2020-10-20', freq='3D')
#pd.date_range(start='2020-07-30', end='2020-10-20', freq='5H')
#pd.date_range(start='2020-07-30', end='2020-10-20', freq='Q')
#pd.date_range(start='2020-07-30', end='2020-10-20', freq='B')    # Business day(월~금)

bdays = pd.date_range(start= 식당.index.min(), end=식당.index.max(), freq='B')

# %%
len(bdays), len(식당.index.unique())
# 35개의 날짜가 수집이 안됨
# Out:
# (515, 480)

# %%
# 3.3. 조건 색인
bdays[~bdays.isin(식당.index.unique())]   # 포함안되는 것들 고르기

# 공휴일인 경우 데이터 미수집 확인
# Out:
# DatetimeIndex(['2013-08-07', '2013-08-08', '2013-08-09', '2013-08-15',
#                '2013-08-16', '2013-09-18', '2013-09-19', '2013-09-20',
#                '2013-10-03', '2013-10-09', '2013-12-25', '2014-01-01',
#                '2014-01-30', '2014-01-31', '2014-04-04', '2014-05-01',
#                '2014-05-05', '2014-05-06', '2014-06-04', '2014-06-06',
#                '2014-08-15', '2014-09-08', '2014-09-09', '2014-09-10',
#                '2014-10-03', '2014-10-09', '2014-12-25', '2015-01-01',
#                '2015-02-18', '2015-02-19', '2015-02-20', '2015-04-03',
#                '2015-05-01', '2015-05-05', '2015-05-25'],
#               dtype='datetime64[ns]', freq=None)

# %%
# 3.3.1. set(집합)
set(bdays) - set(식당.index)

# 3.3.2. List Compression
[ x for x in bdays if x not in 식당.index.unique()]
# Out:
# {Timestamp('2013-08-07 00:00:00', freq='B'),
#  Timestamp('2013-08-08 00:00:00', freq='B'),
#  Timestamp('2013-08-09 00:00:00', freq='B'),
#  Timestamp('2013-08-15 00:00:00', freq='B'),
#  Timestamp('2013-08-16 00:00:00', freq='B'),
#  Timestamp('2013-09-18 00:00:00', freq='B'),
#  Timestamp('2013-09-19 00:00:00', freq='B'),
#  Timestamp('2013-09-20 00:00:00', freq='B'),
#  Timestamp('2013-10-03 00:00:00', freq='B'),
#  Timestamp('2013-10-09 00:00:00', freq='B'),
#  Timestamp('2013-12-25 00:00:00', freq='B'),
#  Timestamp('2014-01-01 00:00:00', freq='B'),
#  Timestamp('2014-01-30 00:00:00', freq='B'),
#  Timestamp('2014-01-31 00:00:00', freq='B'),
#  Timestamp('2014-04-04 00:00:00', freq='B'),
#  Timestamp('2014-05-01 00:00:00', freq='B'),
#  Timestamp('2014-05-05 00:00:00', freq='B'),
#  Timestamp('2014-05-06 00:00:00', freq='B'),
#  Timestamp('2014-06-04 00:00:00', freq='B'),
#  Timestamp('2014-06-06 00:00:00', freq='B'),
#  Timestamp('2014-08-15 00:00:00', freq='B'),
# ...

# %%
# 데이터 탐색 - corner 별 수집횟수 확인
식당.corner.value_counts()
# Out:
# rice & soup 1    1422
# take out         1381
# after school      929
# grill & fry       925
# noodle bar        923
# burger&pizza      913
# rice & soup 2     332
# Name: corner, dtype: int64

# %%
식당[식당.corner == 'rice & soup 2'] # 2014/2/25에 신규 생성된 코너로 추정
# Out:
#            dine_type         corner            menu is_sold_out  use_count  \
# date
# 2014-02-25     lunch  rice & soup 2      두부편육보쌈&무생채           F        200
# 2014-02-26     lunch  rice & soup 2           버섯불고기           F        248
# 2014-02-27     lunch  rice & soup 2           쇠고기국밥           T        249
# 2014-02-28     lunch  rice & soup 2           대구지리탕           T        101
# 2014-03-03     lunch  rice & soup 2            닭살백숙           T        383
# ...              ...            ...             ...         ...        ...
# 2015-07-21     lunch  rice & soup 2          모둠채소쌈밥           F        249
# 2015-07-22     lunch  rice & soup 2           도토리묵밥           F        238
# 2015-07-23     lunch  rice & soup 2          쇠고기영양탕           F        158
# 2015-07-24     lunch  rice & soup 2        훈제오리채소볶음           F        207
# 2015-07-27     lunch  rice & soup 2  생오리고추장불고기&부추생채           F        264
#
# ...

# %% [markdown]
# #### (실습 #4) 날짜 색인
# - 1) 2014년 데이터만 선택하여 출력
# - 2) 2015년 1월 데이터만 선택하여 출력
# - 3) 2014년 8월 1일부터 2014년 9월 25일까지 데이터만 출력
# - 4) 2015년 6월 30일 데이터만 출력

# %%
식당['2014']
# Out:
#             dine_type         corner         menu is_sold_out  use_count  \
# date
# 2014-01-02  breakfast       take out     쿡살라미샌드위치           F         51
# 2014-01-02     dinner     noodle bar      오징어비빔국수           F        111
# 2014-01-02     dinner       take out    날치알캘리포니아롤           F        386
# 2014-01-02      lunch   burger&pizza      갈릭오일파스타           T        142
# 2014-01-02     dinner   burger&pizza      참치김치그라탕           T        151
# ...               ...            ...          ...         ...        ...
# 2014-12-31      lunch     noodle bar       짬뽕&탕수육           F        152
# 2014-12-31      lunch       take out      연어레몬샐러드           F        124
# 2014-12-31     dinner   after school  얼큰김치라면&계란말이           F          2
# 2014-12-31  breakfast  rice & soup 1  북어국&떡갈비엿장구이           F         38
# 2014-12-31     dinner  rice & soup 1          설렁탕           F         28
#
#             pred_count  additional  good  ok  bad  diff_use_pred  year  month  \
# ...

# %%
식당['2015/01']
# Out:
#             dine_type         corner             menu is_sold_out  use_count  \
# date
# 2015-01-02     dinner   after school      참깨라면&볶음김치김밥           F         39
# 2015-01-02      lunch   after school   오징어김치볶음밥&계란후라이           F        158
# 2015-01-02  breakfast  rice & soup 1    감자호박국&소고기야채볶음           F         35
# 2015-01-02      lunch  rice & soup 1  청국장찌개&돼지고기고추장볶음           F        235
# 2015-01-02      lunch     noodle bar        자장면&김치만두찜           F        218
# ...               ...            ...              ...         ...        ...
# 2015-01-30     dinner   burger&pizza       퀘사디아&카레볶음밥           F         36
# 2015-01-30     dinner    grill & fry        추억의도시락비빔밥           F        139
# 2015-01-30  breakfast       take out     샌드위치콤보&음료&과일           F         45
# 2015-01-30      lunch       take out      훈제오리&단호박샐러드           F        265
# 2015-01-30     dinner  rice & soup 1       비지찌개&깻잎고기전           F        145
#
# ...

# %%
식당['2014/08/01':'2014/09/25']
# Out:
#             dine_type         corner         menu is_sold_out  use_count  \
# date
# 2014-08-01     dinner   after school   햄모듬라면&콩도너츠           F        137
# 2014-08-01      lunch   after school  카레라면&비빔채소만두           T        129
# 2014-08-01     dinner    grill & fry     취나물밥&양념장           F         68
# 2014-08-01  breakfast       take out      7곡빵샌드위치           F         39
# 2014-08-01      lunch    grill & fry        더덕비빔밥           F        158
# ...               ...            ...          ...         ...        ...
# 2014-09-25      lunch  rice & soup 2  돼지고기고추장깻잎볶음           F        246
# 2014-09-25      lunch    grill & fry    왕새우&카레라이스           F        321
# 2014-09-25     dinner    grill & fry    황해도식해주비빔밥           F         87
# 2014-09-25  breakfast       take out         샌드위치           F         30
# 2014-09-25      lunch       take out         콥샐러드           F        275
#
#             pred_count  additional  good  ok  bad  diff_use_pred  year  month  \
# ...

# %%
식당.loc['2015/06/30']
# Out:
#             dine_type         corner          menu is_sold_out  use_count  \
# date
# 2015-06-30     dinner       take out      비엔나소시지컵밥           F        116
# 2015-06-30      lunch       take out          콥샐러드           F        281
# 2015-06-30      lunch  rice & soup 1           감자탕           F        230
# 2015-06-30      lunch   after school          짜파게티           F        147
# 2015-06-30      lunch   burger&pizza       콤비네이션피자           F         93
# 2015-06-30     dinner    grill & fry      불고기채소비빔밥           F        145
# 2015-06-30  breakfast       take out  샌드위치콤보&음료&과일           F         60
# 2015-06-30     dinner   after school         햄모둠라면           T        113
# 2015-06-30     dinner   burger&pizza     왕소시지김치그라탕           F         82
# 2015-06-30  breakfast  rice & soup 1    감자계란국*청량고추           F         68
# 2015-06-30      lunch  rice & soup 2     생오리고추장불고기           F        227
# 2015-06-30      lunch     noodle bar          황태짬뽕           F        225
# ...

# %% [markdown]
# ### date_range()를 활용한 고급 기법
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html

# %%
# 특정 기간의 날짜 생성

# %%
# start 날짜를 기준으로 periods 갯수만큼 날짜 생성

# %%
#특정 주기로 날짜를 생성 - freq 인자
# 상세 내용은 https://pandas.pydata.org/pandas-docs/stable/timeseries.html#timeseries-offset-aliases 확인



# D: 일단위
# W: 주 단위 (일요일만 선택)
# W-MON: 주 단위이되, 월요일만 선택
# W-TUE: 주 단위이되, 화요일만 선택. WED, THU, FRI, SAT, SUN 모두 가능
# M: 매달 마지막날만 선택
# MS: 매달 첫째날만 선택
# B: 주중만 선택 (Business day)

# %% [markdown]
# #### (실습 #5 - date_range()) 식당 데이터 중 월요일 데이터만 선택하여 출력

# %%
식당[식당.wday == 0]
# Out:
#            date  dine_type         corner            menu is_sold_out  \
# 5    2013-08-12     dinner     noodle bar            차슈라멘           F
# 6    2013-08-12  breakfast  rice & soup 1          뚝배기순대국           F
# 7    2013-08-12      lunch  rice & soup 1       A:누룽지장각백숙           F
# 8    2013-08-12      lunch     noodle bar           유니자장면           F
# 9    2013-08-12     dinner  rice & soup 1          김치날치알밥           F
# ...         ...        ...            ...             ...         ...
# 6820 2015-07-27      lunch    grill & fry       돼지고기채소비빔밥           F
# 6821 2015-07-27      lunch  rice & soup 2  생오리고추장불고기&부추생채           F
# 6822 2015-07-27  breakfast       take out    샌드위치콤보&음료&과일           F
# 6823 2015-07-27      lunch     noodle bar          김치비빔국수           F
# 6824 2015-07-27      lunch       take out     닭가슴살크랜베리샐러드           F
#
#       use_count  pred_count  additional  good  ok  bad  diff_use_pred  year  \
# ...

# %% [markdown]
# ## (실습 #6) 푸드코트 데이터 분석
# - 1) 전체 기간 동안, 가장 많은 판매량을 올렸던 날 찾기
# - 2) 전체 기간 동안, 아침, 점심, 저녁 메뉴로 가장 인기 있었던 메뉴를 각각 착기
# - 3) 2014년 한 해 동안, 각 코너 별  월별 판매량을 그래프로 시각화하기
# - 4) 매진을 가장 많이 기록한 상위 10개 메뉴와 매진횟수를 출력
# - 5) 2014년도에 가장 많이 팔린 상위 10개 메뉴 구하기
# - 6) 5)에서 구한 상위 10개 메뉴에 대한 월별 판매 추이 그래프 그리기 (하루 평균 판매량)
# - 7) 5)에서 구한 상위 10개 메뉴에 대한 분기별 판매 추이 그래프 그리기 (하루 평균 판매량)

# %% [markdown]
# ### 6-1) 전체 기간 동안, 가장 많은 판매량을 올렸던 날 찾기

# %%
식당.pivot_table(index = 'date', values = 'use_count', aggfunc='sum')\
    .sort_values(by = 'use_count', ascending = False).head(1)
# Out:
#             use_count
# date
# 2013-10-23       4267

# %% [markdown]
# ### 6-2) 전체 기간 동안, 아침, 점심, 저녁 메뉴로 가장 인기 있었던 메뉴를 각각 착기

# %%
식당.pivot_table(index = 'menu', values = 'use_count', aggfunc='sum')\
    .sort_values(by = 'use_count', ascending = False).head(1)
# Out:
#       use_count
# menu
# 콥샐러드      13747

# %%
메뉴 = 식당.pivot_table(index = 'menu', columns = 'dine_type', values = 'use_count', aggfunc='sum')

# %%
아침 = 메뉴.sort_values(by='breakfast', ascending = False).head(1)

# %%
점심 = 메뉴.sort_values(by='lunch', ascending = False).head(1)

# %%
저녁 = 메뉴.sort_values(by='dinner', ascending = False).head(1)

# %%
print('아침 인기 메뉴 :', 아침.index[0])
print('점심 인기 메뉴 :', 점심.index[0])
print('저녁 인기 메뉴 :', 저녁.index[0])
# Out:
# 아침 인기 메뉴 : 샌드위치콤보&음료&과일
# 점심 인기 메뉴 : 콥샐러드
# 저녁 인기 메뉴 : 로제컵파스타&새우튀김

# %% [markdown]
# ### 6-3) 2014년 한 해 동안, 각 코너 별  월별 판매량을 그래프로 시각화하기

# %%
식당.set_index('date', inplace = True)

# %%
식당14 = 식당['2014']

# %%
식당14.head()
# Out:
#             dine_type        corner       menu is_sold_out  use_count  \
# date
# 2014-01-02  breakfast      take out   쿡살라미샌드위치           F         51
# 2014-01-02     dinner    noodle bar    오징어비빔국수           F        111
# 2014-01-02     dinner      take out  날치알캘리포니아롤           F        386
# 2014-01-02      lunch  burger&pizza    갈릭오일파스타           T        142
# 2014-01-02     dinner  burger&pizza    참치김치그라탕           T        151
#
#             pred_count  additional  good  ok  bad  diff_use_pred  year  month  \
# date
# 2014-01-02           0           0     0   0    0            -51  2014      1
# 2014-01-02           0           0     0   0    0           -111  2014      1
# 2014-01-02           0           0     0   0    0           -386  2014      1
# 2014-01-02           0           0     0   0    0           -142  2014      1
# 2014-01-02           0           0     0   0    0           -151  2014      1
#
#             day  wday
# date
# 2014-01-02    2     3
# ...

# %%
# 코너판매14 = 식당14.pivot_table(index = 'corner', columns = 'month', values = 'use_count', aggfunc='sum')
코너판매14 = 식당14.pivot_table(index = 'month', columns = 'corner', values = 'use_count', aggfunc='sum').fillna(0)

# %%
코너판매14
# Out:
# corner  after school  burger&pizza  grill & fry  noodle bar  rice & soup 1  \
# month
# 1             6799.0        5549.0       8896.0      7985.0        19027.0
# 2             6731.0        5497.0       8591.0      7437.0        16191.0
# 3             7180.0        6447.0       9316.0      7622.0        12832.0
# 4             6826.0        6145.0       9218.0      7159.0        11837.0
# 5             5220.0        4505.0       8317.0      6614.0         9877.0
# 6             5389.0        4898.0       8684.0      6772.0        11046.0
# 7             6702.0        7228.0      11008.0      9254.0        13793.0
# 8             5161.0        6436.0       8740.0      7229.0        11623.0
# 9             4276.0        5855.0       7600.0      5751.0         9232.0
# 10            5014.0        6441.0       8261.0      6303.0        11550.0
# 11            4619.0        5707.0       8491.0      6040.0        10674.0
# ...

# %%
코너판매14.plot(xticks = 코너판매14.index)
# rice & soup 2 는 2월부터 판매

# %% [markdown]
# ### 6-4) 매진을 가장 많이 기록한 상위 10개 메뉴와 매진횟수를 출력

# %%
식당[식당.is_sold_out == 'T']
# Out:
#            dine_type         corner       menu is_sold_out  use_count  \
# date
# 2013-10-23    dinner     noodle bar     바지락칼국수           T        170
# 2013-10-28    dinner   after school  어묵떡볶이 set           T        147
# 2013-10-28    dinner   burger&pizza    마늘새우볶음밥           T        138
# 2013-10-29    dinner   burger&pizza       더블버거           T        120
# 2013-10-29     lunch   after school  떡만두라면 SET           T        175
# ...              ...            ...        ...         ...        ...
# 2015-07-15    dinner   burger&pizza     새우또디아랩           T         90
# 2015-07-20    dinner   burger&pizza        라자냐           T        159
# 2015-07-23     lunch    grill & fry     *인도요리*           T        307
# 2015-07-24    dinner  rice & soup 1  돼지고기고추장볶음           T        148
# 2015-07-27     lunch   burger&pizza      매콤돈가스           T        282
#
#             pred_count  additional  good  ok  bad  diff_use_pred  year  month  \
# date
# ...

# %%
매진 = 식당[식당.is_sold_out == 'T']  #[['menu', 'is_sold_out']]
# 매진.is_sold_out.replace('T',1, inplace = True)

# %%
                                                                            # 'sum')\
매진순위 = 매진.pivot_table(index='menu', values = 'is_sold_out', aggfunc = 'count')\
    .sort_values(by = 'is_sold_out', ascending = False)

# %%
매진순위.head(10)
# Out:
#              is_sold_out
# menu
# 치즈돈가스                 14
# 등심돈가스                 13
# 김치볶음밥&계란후라이           11
# 고르곤졸라피자                9
# 고구마돈가스                 9
# 양식돈가스                  8
# 카레라이스                  7
# 치즈버거                   7
# 햄버거스테이크                6
# 간자장면                   6

# %%
# 방법 2
매진.menu.value_counts().head(10)
# Out:
# 치즈돈가스          14
# 등심돈가스          13
# 김치볶음밥&계란후라이    11
# 고르곤졸라피자         9
# 고구마돈가스          9
# 양식돈가스           8
# 카레라이스           7
# 치즈버거            7
# 사골떡만두국          6
# 간자장면            6
# Name: menu, dtype: int64

# %% [markdown]
# ### 6-5) 2014년도에 가장 많이 팔린 상위 10개 메뉴 구하기

# %%
식당14 = 식당['2014']

# %%
상위14 =식당14.pivot_table(index = 'menu', values = 'use_count', aggfunc='sum')\
    .sort_values(by = 'use_count', ascending = False)

# %%
상위14.head(10)
# Out:
#              use_count
# menu
# 돈가스샐러드            7949
# 로제컵파스타&새우튀김       7560
# 훈제오리&단호박샐러드       7448
# 콥샐러드              7317
# 참치김치찌개            5783
# 토마토미트볼컵파스타        5391
# 등심돈가스             5007
# 미트볼라이스            4950
# 돈안심샐러드            4113
# 불고기채소비빔밥          3993

# %% [markdown]
# ### 6-6) 5)에서 구한 상위 10개 메뉴에 대한 월별 판매 추이 그래프 그리기 (하루 평균 판매량)

# %%
메뉴 = 상위14.head(10)
메뉴.index
# Out:
# Index(['돈가스샐러드', '로제컵파스타&새우튀김', '훈제오리&단호박샐러드', '콥샐러드', '참치김치찌개', '토마토미트볼컵파스타',
#        '등심돈가스', '미트볼라이스', '돈안심샐러드', '불고기채소비빔밥'],
#       dtype='object', name='menu')

# %%
월별판매 = 식당14[식당14.menu.isin(메뉴.index)]

# %%
최종 = 월별판매.pivot_table(index = 'month', columns = 'menu', values = 'use_count', aggfunc='mean')

# %%
matplotlib.rcParams['font.family'] = 'Malgun Gothic'

최종.fillna(0).plot(figsize = (15,10))

# %% [markdown]
# ### 6-7) 5)에서 구한 상위 10개 메뉴에 대한 분기별 판매 추이 그래프 그리기 (하루 평균 판매량)

# %%
메뉴.index
# Out:
# Index(['돈가스샐러드', '로제컵파스타&새우튀김', '훈제오리&단호박샐러드', '콥샐러드', '참치김치찌개', '토마토미트볼컵파스타',
#        '등심돈가스', '미트볼라이스', '돈안심샐러드', '불고기채소비빔밥'],
#       dtype='object', name='menu')

# %%
분기판매 = 식당14[식당14.menu.isin(메뉴.index)]

# %%
분기판매['quarter'] = ((분기판매.month)-1)//3 +1
# Out:
# <ipython-input-146-77073a5c2e9a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   분기판매['quarter'] = ((분기판매.month)-1)//3 +1

# %%
최종2 = 분기판매.pivot_table(index = 'quarter', columns = 'menu', values = 'use_count', aggfunc = 'mean')

# %%
최종2.fillna(0).plot(figsize=(15,7))

# %%
# 방법 2

# %%
# 분기(quarter) 정보 구하기
now = datetime.now()
pd.Timestamp(now).quarter
# Out:
# 3

# %%
분기판매['quarter2'] = 분기판매.index.quarter
# Out:
# <ipython-input-156-bc5109a12309>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   분기판매['quarter2'] = 분기판매.index.quarter

# %%
분기판매.head()
# Out:
#            dine_type         corner         menu is_sold_out  use_count  \
# date
# 2014-01-02     lunch  rice & soup 1       참치김치찌개           F        683
# 2014-01-06    dinner  rice & soup 1       참치김치찌개           F        298
# 2014-01-07    dinner       take out       미트볼라이스           F        491
# 2014-01-09     lunch       take out  훈제오리&단호박샐러드           F        269
# 2014-01-17     lunch       take out         콥샐러드           F        274
#
#             pred_count  additional  good  ok  bad  diff_use_pred  year  month  \
# date
# 2014-01-02           0           0     0   0    0           -683  2014      1
# 2014-01-06           0           0     0   0    0           -298  2014      1
# 2014-01-07           0           0     0   0    0           -491  2014      1
# 2014-01-09           0           0     0   0    0           -269  2014      1
# 2014-01-17           0           0     0   0    0           -274  2014      1
#
#             day  wday  quarter  quarter2
# date
# ...

# %%
최종3 = 분기판매.pivot_table(index = 'quarter2', columns = 'menu', values = 'use_count', aggfunc = 'mean').fillna(0)

# %%
최종3.plot(xticks = 최종3.index, figsize = (15,7))

# %%
최종3.T.plot(kind='barh', stacked=True)
