# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib
matplotlib.rcParams['font.family'].insert(0, 'Malgun Gothic') 
# %matplotlib inline

# %% [markdown]
# # 1. openAPI 활용 및 json 데이터 읽기
# ## API : Application Programming Interface
# ## 서울시 데이터 포털에서 공공 API 활용하기
# ### 서울시 동별 인구통계
# ### http://data.seoul.go.kr/dataList/datasetView.do?infId=10043&srvType=S&serviceKind=2&currentPageNo=1

# %%
import requests

# %%
url = 'http://openapi.seoul.go.kr:8088'
api_key = 'sample'   # 개인 인증키 발급받은 후 입력
return_format = 'json'
service_id = 'octastatapi10043'
start_idx = '1'
end_idx = '5'

request_url = '/'.join([url, api_key, return_format, service_id, start_idx, end_idx])
request_url
# Out:
# 'http://openapi.seoul.go.kr:8088/sample/json/octastatapi10043/1/5'

# %%
response = requests.get(request_url)

# %%
response.text
# Out:
# '{"octastatapi10043":{"list_total_count":1801,"RESULT":{"CODE":"INFO-000","MESSAGE":"정상 처리되었습니다"},"row":[{"GIGAN":"\ufeff2020.1-4","JACHIGU":"합계","DONG":"합계","SEDAE":"4,354,006","GYE_1":"10,013,781","NAMJA_1":"4,874,995","YEOJA_1":"5,138,786","GYE_2":"9,733,655","NAMJA_2":"4,742,217","YEOJA_2":"4,991,438","GYE_3":"280,126","NAMJA_3":"132,778","YEOJA_3":"147,348","SEDAEDANGINGU":"2.24","N_65SEISANGGORYEONGJA":"1,518,239"},{"GIGAN":"2020.1-4","JACHIGU":"종로구","DONG":"소계","SEDAE":"74,151","GYE_1":"161,984","NAMJA_1":"78,271","YEOJA_1":"83,713","GYE_2":"151,217","NAMJA_2":"73,704","YEOJA_2":"77,513","GYE_3":"10,767","NAMJA_3":"4,567","YEOJA_3":"6,200","SEDAEDANGINGU":"2.04","N_65SEISANGGORYEONGJA":"28,073"},{"GIGAN":"2020.1-4","JACHIGU":"종로구","DONG":"사직동","SEDAE":"4,668","GYE_1":"9,841","NAMJA_1":"4,469","YEOJA_1":"5,372","GYE_2":"9,553","NAMJA_2":"4,309","YEOJA_2":"5,244","GYE_3":"288","NAMJA_3":"160","YEOJA_3":"128","SEDAEDANGINGU":"2.05","N_65SEISANGGORYEONGJA":"1,818"},{"GIGAN":"2020.1-4","JACHIGU":"종로구","DONG":"삼청동","SEDAE":"1,375","GYE_1":"2,993","NAMJA_1":"1,435","YEOJA_1":"1,558","GYE_2":"2,749","NAMJA_2":"1,320","YEOJA_2":"1,429","GYE_3":"244","NAMJA_3":"115","YEOJA_3":"129","SEDAEDANGINGU":"2","N_65SEISANGGORYEONGJA":"679"},{"GIGAN":"2020.1-4","JACHIGU":"종로구","DONG":"부암동","SEDAE":"4,346","GYE_1":"10,597","NAMJA_1":"5,042","YEOJA_1":"5,555","GYE_2":"10,164","NAMJA_2":"4,835","YEOJA_2":"5,329","GYE_3":"433","NAMJA_3":"207","YEOJA_3":"226","SEDAEDANGINGU":"2.34","N_65SEISANGGORYEONGJA":"1,799"}]}}'

# %% [markdown]
# ### json (Java Script Object Notation)
#
# ### 1) json 설명: https://ko.wikipedia.org/wiki/JSON
# ### 2) json online editor: https://jsoneditoronline.org/

# %%
sample = ' { \
    "이름": "김지아", \
    "나이": 25, \
    "성별": "여", \
    "주소": "서울특별시 양천구 목동",\
    "특기": ["농구", "도술"],\
    "가족관계": {"#": 2, "아버지": "홍판서", "어머니": "춘섬"},\
    "회사": "경기 수원시 팔달구 우만동"\
 }'

# %%
import json

# %%
js = json.loads(sample)

# %%
print(type(js))
js
# Out:
# <class 'dict'>
# {'이름': '김지아',
#  '나이': 25,
#  '성별': '여',
#  '주소': '서울특별시 양천구 목동',
#  '특기': ['농구', '도술'],
#  '가족관계': {'#': 2, '아버지': '홍판서', '어머니': '춘섬'},
#  '회사': '경기 수원시 팔달구 우만동'}

# %%
js['이름'], js['가족관계']['아버지']
# Out:
# ('김지아', '홍판서')

# %%
jsondata = response.json()

# %%
type(jsondata)
# Out:
# dict

# %%
DataFrame(jsondata)
# Out:
#                                                    octastatapi10043
# RESULT                {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'}
# list_total_count                                               1801
# row               [{'GIGAN': '﻿2020.1-4', 'JACHIGU': '합계', 'DONG...

# %%
DataFrame(jsondata['octastatapi10043']['row'])
# Out:
#        GIGAN JACHIGU DONG      SEDAE       GYE_1    NAMJA_1    YEOJA_1  \
# 0  ﻿2020.1-4      합계   합계  4,354,006  10,013,781  4,874,995  5,138,786
# 1   2020.1-4     종로구   소계     74,151     161,984     78,271     83,713
# 2   2020.1-4     종로구  사직동      4,668       9,841      4,469      5,372
# 3   2020.1-4     종로구  삼청동      1,375       2,993      1,435      1,558
# 4   2020.1-4     종로구  부암동      4,346      10,597      5,042      5,555
#
#        GYE_2    NAMJA_2    YEOJA_2    GYE_3  NAMJA_3  YEOJA_3 SEDAEDANGINGU  \
# 0  9,733,655  4,742,217  4,991,438  280,126  132,778  147,348          2.24
# 1    151,217     73,704     77,513   10,767    4,567    6,200          2.04
# 2      9,553      4,309      5,244      288      160      128          2.05
# 3      2,749      1,320      1,429      244      115      129             2
# 4     10,164      4,835      5,329      433      207      226          2.34
#
#   N_65SEISANGGORYEONGJA
# 0             1,518,239
# 1                28,073
# 2                 1,818
# 3                   679
# 4                 1,799

# %% [markdown]
# # 2. folium 을 활용한 지도 시각화

# %%
#folium 라이브러리 설치
# anaconda prompt에서 'pip install folium' 실행
import folium

# %%
map1 = folium.Map(location=[37.566535, 126.9779691999996], zoom_start = 15) #, tiles = 'cartodbpositron')

# %%
folium.Marker([37.566, 126.977], popup = '테스트지점').add_to(map1)

# %%
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
조사지점 = pd.read_excel('data/서울시유동인구/4_유동인구_조사지점정보_2015.xlsx', skiprows=[0,1,3])

# %%
조사지점100 = 조사지점[['조사지점명', 'X좌표', 'Y좌표']][:100]

# %%
# 위치 정보 변환
# 필요한 라이브러리(pyproj)를 설치
# pip install pyproj

from pyproj import Proj, transform
#from pyproj import Proj, Transformer

# %%
def convert(x,y):
    inProj = Proj(init = 'epsg:5181')
    outProj = Proj(init = 'epsg:4326')
    x2, y2 = transform(inProj, outProj, x, y)
    #transformer = Transformer.from_crs("epsg:5181", "epsg:4326")
    #x2, y2 = transformer.transform(x, y)
    return [y2, x2]

# %%
convert(196423.97707, 455511.52968)
# Out:
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# [37.59916962231494, 126.95950527754184]

# %%
조사지점100.set_index('조사지점명', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-80894860eaea> in <module>
# ----> 1 조사지점100.set_index('조사지점명', inplace = True)
#
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['조사지점명'] are in the columns"

# %%
조사지점100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 신흥모피명품전문크리닝. to 파파존스피자
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X좌표     100 non-null    float64
#  1   Y좌표     100 non-null    float64
#  2   위경도     100 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 3.1+ KB

# %%
조사지점100['위경도'] = 조사지점100.apply(lambda X: convert(X.X좌표, X.Y좌표), axis = 1)
# Out:
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# ...
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# c:\users\ryzen\appdata\local\programs\python\python38\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# <ipython-input-50-215468d8716a>:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2, y2 = transform(inProj, outProj, x, y)

# %%
조사지점100.head()
# Out:
#                             X좌표           Y좌표  \
# 조사지점명
# 신흥모피명품전문크리닝.       196423.97707  455511.52968
# GS25               196315.80243  455621.38262
# 세검정정류장             196357.17125  455680.82580
# 안성타워內 굿모닝파워공인중개사.  197904.19277  456718.34996
# 복실 손뜨기.            196360.44943  456405.89296
#
#                                                         위경도
# 조사지점명
# 신흥모피명품전문크리닝.        [37.59916962231494, 126.95950527754184]
# GS25               [37.600158960377534, 126.95827976042075]
# 세검정정류장              [37.60069470246644, 126.95874792945385]
# 안성타워內 굿모닝파워공인중개사.    [37.6100475136769, 126.97626371692706]
# 복실 손뜨기.              [37.60722749795384, 126.9587814478111]

# %%
for index, row in 조사지점100.iterrows():
    print('index :', index)
    print('row :', row.위경도)
    folium.Marker(row['위경도'], popup = index).add_to(map1)
# Out:
# index : 신흥모피명품전문크리닝.
# row : [37.59916962231494, 126.95950527754184]
# index : GS25
# row : [37.600158960377534, 126.95827976042075]
# index : 세검정정류장
# row : [37.60069470246644, 126.95874792945385]
# index : 안성타워內 굿모닝파워공인중개사.
# row : [37.6100475136769, 126.97626371692706]
# index : 복실 손뜨기.
# row : [37.60722749795384, 126.9587814478111]
# index : 24시 동대문 설렁탕.
# row : [37.57189585575478, 127.01093986576858]
# index : 서울전문학교.
# row : [37.5742705577399, 127.01909338960732]
# index : 서울 종묘농약
# row : [37.57074463392461, 127.00262338744986]
# index : 서울 종묘농약
# row : [37.57074463392461, 127.00262338744986]
# index : 삼성카드빌딩
# row : [37.57596032499436, 126.99927072516557]
# index : TIFS(성우빌딩)
# row : [37.58240785755109, 126.99774653014185]
# index : TIFS(성우빌딩)
# row : [37.58240785755109, 126.99774653014185]
# index : KFC
# row : [37.581860705095, 127.00229395758608]
# index : 영안빌딩(미샤)
# row : [37.568748573616745, 126.9851493859376]
# index : 영안빌딩(미샤)
# row : [37.568748573616745, 126.9851493859376]
# index : 우리은행
# row : [37.569969604413636, 126.98568750376982]
# index : 종묘공원
# row : [37.57083848702517, 126.9956262179747]
# index : U+
# row : [37.5702911940144, 126.99061873346157]
# index : U+
# row : [37.5702911940144, 126.99061873346157]
# index : 성종사
# row : [37.57271181215453, 126.98289942476514]
# index : 금호미술관
# row : [37.57924228275812, 126.97952735607045]
# index : 남원추어탕 맞은편.
# row : [37.58519916025033, 126.97133919632157]
# index : 대영빌딩
# row : [37.57579860405918, 126.97102700952424]
# index : 픽스딕스.
# row : [37.57024959111768, 126.97949158385843]
# index : 세실치과의원
# row : [37.570708560950834, 126.96185975430792]
# index : 금호아시아나 1관.
# row : [37.56988722654926, 126.9730327562972]
# index : lg광화문 빌딩
# row : [37.56997204029241, 126.9713901771636]
# index : 안경마을 콘텍트
# row : [37.57288825361462, 126.97828956164231]
# index : 세란병원.
# row : [37.57513866158985, 126.95742839895145]
# index : 에이스조명
# row : [37.569396473333605, 126.99770582864966]
# index : 매헌빌딩
# row : [37.57084518181747, 126.99853543350594]
# index : 경복궁 돌담길 경복궁동문 정류장에서 춘추관앞 방향으로 60M
# row : [37.57734777778048, 126.9792588602516]
# index : 버스정류장에서 도로 바라보고 좌측20미터 일성툴
# row : [37.56867506757758, 126.99340260436438]
# index : 우리은행
# row : [37.57031951072166, 126.9855129559265]
# index : Tworld 대리점
# row : [37.56998507313723, 126.9895927339847]
# index : 준코 뮤직타운
# row : [37.570310598668044, 126.98552439699829]
# index : 준코 뮤직타운
# row : [37.570310598668044, 126.98552439699829]
# index : 광화문 빌딩
# row : [37.569833277540994, 126.9761578394427]
# index : 서울보증보험 조형물
# row : [37.57346674060522, 127.0006059696071]
# index : 효제초교 지하주차장입구
# row : [37.573269180935895, 127.00281613185898]
# index : 대일빌딩
# row : [37.57266487076183, 127.00594865775517]
# index : 운촌빌딩
# row : [37.573640412934715, 127.00516588399343]
# index : 국일관
# row : [37.569661607432664, 126.98969898441098]
# index : 성제종합휘장타운
# row : [37.56879641659778, 126.98967671116078]
# index : 안국역 6번 출구 건너편
# row : [37.576073818163, 126.98407636859098]
# index : 농협중앙회 앞
# row : [37.57232349141933, 126.98384430465852]
# index : SINDO 앞
# row : [37.579463741864764, 126.97285594574947]
# index : 감사원뒷길
# row : [37.586659553277286, 126.98495154903124]
# index : 서울 닭 문화관
# row : [37.58283058369664, 126.98500354008432]
# index : 애지중지
# row : [37.58052957614798, 126.98671039249953]
# index : 창덕궁
# row : [37.57830895498707, 126.98938968931509]
# index : 정부 중앙청사 후문
# row : [37.574948782100286, 126.97484251034]
# index : 새마을식당
# row : [37.57245477057444, 126.97505782647227]
# index : 소송동 스타벅스
# row : [37.57191697145218, 126.98163102898371]
# index : 덕성여대, 교동초교, 사이 골목
# row : [37.57528780264267, 126.98802672661257]
# index : 일등 의상실
# row : [37.575569526717906, 126.98935878757432]
# index : 동아일보
# row : [37.56992740808484, 126.97766212376528]
# index : 동아일보
# row : [37.56992740808484, 126.97766212376528]
# index : 이디야 커피
# row : [37.571093729433215, 126.979163097881]
# index : 명륜동2가 새마을금고
# row : [37.58425500880319, 127.00093729509886]
# index : 한가람 노래바
# row : [37.5713892757661, 126.9789552980624]
# index : 일식레스토랑
# row : [37.572181300636124, 126.98721972969368]
# index : 웰빙콩나물
# row : [37.568668150700496, 126.99048215790562]
# index : 종로 골뱅이
# row : [37.569600067936115, 126.99198646787178]
# index : 태양전기
# row : [37.58788405910937, 126.99962063220924]
# index : 태양전기
# row : [37.58788405910937, 126.99962063220924]
# index : 더페이스샵
# row : [37.58351681408267, 127.00101509365467]
# index : 더페이스샵
# row : [37.58351681408267, 127.00101509365467]
# index : 한의원
# row : [37.570603848164524, 126.99876506935468]
# index : 동대문종합시장앞 동대문역 6번출구 전방 10m 가판대
# row : [37.57108851421545, 127.01029396489619]
# index : cafe nanuri
# row : [37.58310456094619, 126.98333547159028]
# index : cafe nanuri
# row : [37.58310456094619, 126.98333547159028]
# index : 식당
# row : [37.577565830109826, 127.01554056232857]
# index : 작은 스위스 요리전문점
# row : [37.58024444008435, 127.00402510039567]
# index : 외환은행 앞
# row : [37.573533049007246, 126.9726430725664]
# index : Fdex 앞
# row : [37.57393349730415, 126.97310171995724]
# index : 관훈클럽신영기금회관
# row : [37.573548519399566, 126.98484651797177]
# index : 35번지 100호 주택
# row : [37.5836379026399, 126.98249037705371]
# index : 茂
# row : [37.58148410212569, 126.9845463028057]
# index : 상원빌라트
# row : [37.58090645475569, 126.98862998539107]
# index : 출애굽 교회
# row : [37.573824458599816, 127.0152954778212]
# index : 광남 한의원
# row : [37.571445644182035, 127.0056139322599]
# index : 승진문구사 건물 입구
# row : [37.57054747874864, 127.00275053892372]
# index : 도한사
# row : [37.573997527015614, 126.98467061193506]
# index : 도한사
# row : [37.573997527015614, 126.98467061193506]
# index : 아시아나 항공 정자
# row : [37.56989830344526, 126.97327032608675]
# index : 태화빌딩
# row : [37.56514490097383, 127.01391557937141]
# index : 성동공업고등학교정문 우측 담벽
# row : [37.56894756813416, 127.01610680536895]
# index : 도로교통공단
# row : [37.563962574520914, 127.02452596570507]
# index : 돈신댓잎갈비
# row : [37.55985168856771, 127.01450600021566]
# index : 화남빌딩
# row : [37.55828309989844, 126.9731807258612]
# index : GS자이공인중개사
# row : [37.554264690543405, 126.96598120632711]
# index : 롯데마트
# row : [37.55577862068171, 126.97012529204075]
# index : 보영약국
# row : [37.567805174511996, 127.0023795887703]
# index : 로쉬치킨.호프
# row : [37.56606487058502, 127.00650047132962]
# index : Molinari Cafe
# row : [37.55794322142663, 126.98283988680996]
# index : LG CNS 건물앞 주차장
# row : [37.55979632444049, 126.9824864564388]
# index : 신일빌딩
# row : [37.560873929357435, 126.98625225843381]
# index : 원조장충동 할머니집
# row : [37.560265231754926, 127.00579649980591]
# index : 파파존스피자
# row : [37.55811829543745, 127.00764727910428]

# %%
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 3. 서울시 유동인구 분석

# %% [markdown]
# ## 데이터 적재

# %% [markdown]
# ## 3.2 데이터 탐색

# %% [markdown]
# ### 3.2.1 유동인구 데이터 탐색

# %% [markdown]
# ### 3.2.2 조사지점 데이터 탐색

# %% [markdown]
# ### 3.2.3 데이터 합치기 - 분석에 필요한 컬럼들만 선택 (어떤 분석을 할지에 따라 변경 가능함)

# %% [markdown]
# ## (실습 #1) 유동인구를 요일과 시간대 별로 분석하여, 유동인구가 가장 많은 상위 10개의 요일과 시간대를 출력. (e.g., 금요일 18시-19시가 유동인구가 가장 많음.)

# %% [markdown]
# ## (실습 #2) 서울시 각 구별 전체 유동인구 분석
# ### 구별로 조사지점의 개수가 다르므로, 조사지점 당 평균 유동인구수로 분석

# %% [markdown]
# ## (실습 #3) 서울시 각 구별로 출퇴근 시간의 유동인구 분석 (출퇴근 시간은 7시-10시, 18시-21시로 가정함)

# %% [markdown]
# ## (실습 #4) 평일 유동인구와 주말 유동인구를 분석하여, 그 차이가 가장 많이 나는 상위 5개 구 정보를 출력

# %% [markdown]
# ## (실습 #5) 유동인구의 수와 보행환경 정보를 분석 (보행환경 정보는 유동인구상세로그_2015.xlsx의 보행환경 컬럼 참고. 매우불만족(1), 약간불만족(2), 보통(3), 약간만족(4), 매우만족(5) )
# ### 5.1 보행 환경 개선이 시급한 곳 10군데를 선정.
# ### 5.2 보행환경점수가 가장 낮은 자치구 5개 찾기
